# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Pandas for Exploratory Data Analysis I
#
#
# Pandas is the most prominent Python library for exploratory data analysis (EDA). The functions Pandas supports are integral to understanding, formatting, and preparing our data. Formally, we use Pandas to investigate, wrangle, munge, and clean our data. Pandas is the Swiss Army Knife of data manipulation!
#
#
# We'll have two coding-heavy sessions on Pandas. In this one, we'll use Pandas to:
#  - Read in a dataset
#  - Investigate a dataset's integrity
#  - Filter, sort, and manipulate a DataFrame's series

# %% [markdown]
# ## About the Dataset: Adventureworks Cycles
#
# <img align="right" src="http://lh6.ggpht.com/_XjcDyZkJqHg/TPaaRcaysbI/AAAAAAAAAFo/b1U3q-qbTjY/AdventureWorks%20Logo%5B5%5D.png?imgmax=800">
#
# For today's Pandas exercises, we will be using a dataset developed by Microsoft for training purposes in SQL server, known the [Adventureworks Cycles 2014OLTP Database](https://github.com/Microsoft/sql-server-samples/releases/tag/adventureworks). It is based on a fictitious company called Adventure Works Cycles (AWC), a multinational manufacturer and seller of bicycles and accessories. The company is based in Bothell, Washington, USA and has regional sales offices in several countries. We will be looking at a single table from this database, the Production.Product table, which outlines some of the products this company sells.
#
# A full data dictionary can be viewed [here](https://www.sqldatadictionary.com/AdventureWorks2014/).

# %% [markdown]
# Let's take a closer look at the Production.Product table [data dictionary](https://www.sqldatadictionary.com/AdventureWorks2014/Production.Product.html), which is a description of the fields (columns) in the table (the .csv file we will import below):
# - **ProductID** - Primary key for Product records.
# - **Name** - Name of the product.
# - **ProductNumber** - Unique product identification number.
# - **MakeFlag** - 0 = Product is purchased, 1 = Product is manufactured in-house.
# - **FinishedGoodsFlag** - 0 = Product is not a salable item. 1 = Product is salable.
# - **Color** - Product color.
# - **SafetyStockLevel** - Minimum inventory quantity.
# - **ReorderPoint** - Inventory level that triggers a purchase order or work order.
# - **StandardCost** - Standard cost of the product.
# - **ListPrice** - Selling price.
# - **Size** - Product size.
# - **SizeUnitMeasureCode** - Unit of measure for the Size column.
# - **WeightUnitMeasureCode** - Unit of measure for the Weight column.
# - **DaysToManufacture** - Number of days required to manufacture the product.
# - **ProductLine** - R = Road, M = Mountain, T = Touring, S = Standard
# - **Class** - H = High, M = Medium, L = Low
# - **Style** - W = Womens, M = Mens, U = Universal
# - **ProductSubcategoryID** - Product is a member of this product subcategory. Foreign key to ProductSubCategory.ProductSubCategoryID.
# - **ProductModelID** - Product is a member of this product model. Foreign key to ProductModel.ProductModelID.
# - **SellStartDate** - Date the product was available for sale.
# - **SellEndDate** - Date the product was no longer available for sale.
# - **DiscontinuedDate** - Date the product was discontinued.
# - **rowguid** - ROWGUIDCOL number uniquely identifying the record. Used to support a merge replication sample.
# - **ModifiedDate** - Date and time the record was last updated.

# %% [markdown]
# ## Importing Pandas
#
# To [import a library](https://docs.python.org/3/reference/import.html), we write `import` and the library name. For Pandas, is it common to name the library `pd` so that when we reference a function from the Pandas library, we only write `pd` to reference the aliased [namespace](https://docs.python.org/3/tutorial/classes.html#python-scopes-and-namespaces) -- not `pandas`.

# %%
import pandas as pd
# %matplotlib inline

# %%
# we can see the details about the imported package by referencing its private class propertys:
print(f'I am using {pd.__name__} \
Version: {pd.__version__}.\n\
It is installed at: {pd.__path__}')
# Out:
# I am using pandas Version: 1.1.3.
# It is installed at: ['C:\\Users\\georg\\anaconda3\\lib\\site-packages\\pandas']

# %% [markdown]
# ## Reading in Data
#
# Pandas dramatically simplifies the process of reading in data. When we say "reading in data," we mean loading a file into our machine's memory.
#
# When you have a CSV, for example, and then you double-click to open it in Microsoft Excel, the open file is "read into memory." You can now manipulate the CSV.
#
# When we read data into memory in Python, we are creating an object. We will soon explore this object. _(And, as an aside, when we have a file that is greater than the size of our computer's memory, this is approaching "Big Data.")_

# %% [markdown]
# Because we are working with a CSV, we will use the [read CSV](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) method.<br>A [delimiter](https://en.wikipedia.org/wiki/Delimiter-separated_values) is a character that separates fields (columns) in the imported file. Just because a file says `.csv` does not necessarily mean that a comma is used as the delimiter. In this case, we have a tab character as the delimiter for our columns, so we will be using `sep='\t'` to tell pandas to 'cut' the columns every time it sees a [tab character in the file](http://vim.wikia.com/wiki/Showing_the_ASCII_value_of_the_current_character).

# %%
# read the dataset as a DataFrame into a variable named 'prod'
prod = pd.read_csv('product_data.csv', sep='\t')

# %%
# show the head of this dataset
prod.head(1)
# Out:
#    ProductID             Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 0          1  Adjustable Race       AR-5381         0                  0
#
#   Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  ...  \
# 0   NaN              1000           750           0.0        0.0  ...
#
#   ProductLine Class Style  ProductSubcategoryID  ProductModelID  \
# 0         NaN   NaN   NaN                   NaN             NaN
#
#          SellStartDate SellEndDate DiscontinuedDate  \
# 0  2008-04-30 00:00:00         NaN              NaN
#
#                                   rowguid                   ModifiedDate
# 0  {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}  2014-02-08 10:01:36.827000000
#
# [1 rows x 25 columns]

# %%
prod.tail()
# Out:
#      ProductID                Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 499        995   ML Bottom Bracket       BB-8107         1                  1
# 500        996   HL Bottom Bracket       BB-9108         1                  1
# 501        997  Road-750 Black, 44    BK-R19B-44         1                  1
# 502        998  Road-750 Black, 48    BK-R19B-48         1                  1
# 503        999  Road-750 Black, 52    BK-R19B-52         1                  1
#
#      Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  ...  \
# 499    NaN               500           375       44.9506     101.24  ...
# 500    NaN               500           375       53.9416     121.49  ...
# 501  Black               100            75      343.6496     539.99  ...
# 502  Black               100            75      343.6496     539.99  ...
# 503  Black               100            75      343.6496     539.99  ...
#
#     ProductLine Class Style  ProductSubcategoryID  ProductModelID  \
# 499         NaN    M    NaN                   5.0            96.0
# 500         NaN    H    NaN                   5.0            97.0
# 501          R     L     U                    2.0            31.0
# 502          R     L     U                    2.0            31.0
# 503          R     L     U                    2.0            31.0
#
#            SellStartDate SellEndDate DiscontinuedDate  \
# 499  2013-05-30 00:00:00         NaN              NaN
# 500  2013-05-30 00:00:00         NaN              NaN
# 501  2013-05-30 00:00:00         NaN              NaN
# 502  2013-05-30 00:00:00         NaN              NaN
# 503  2013-05-30 00:00:00         NaN              NaN
#
#                                     rowguid                   ModifiedDate
# 499  {71AB847F-D091-42D6-B735-7B0C2D82FC84}  2014-02-08 10:01:36.827000000
# 500  {230C47C5-08B2-4CE3-B706-69C0BDD62965}  2014-02-08 10:01:36.827000000
# 501  {44CE4802-409F-43AB-9B27-CA53421805BE}  2014-02-08 10:01:36.827000000
# 502  {3DE9A212-1D49-40B6-B10A-F564D981DBDE}  2014-02-08 10:01:36.827000000
# 503  {AE638923-2B67-4679-B90E-ABBAB17DCA31}  2014-02-08 10:01:36.827000000
#
# [5 rows x 25 columns]

# %% [markdown]
# *Documentation Pause*
#
# How did we know how to use `pd.read_csv`? Let's take a look at the [documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html). Note the first argument required (`filepath`).
# > Take a moment to dissect other arguments and options when reading in data.

# %% [markdown]
# We have just created a data structure called a `DataFrame`. See?

# %%
# show the type of this 'prod' dataset
type(prod)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Inspecting our DataFrame: The basics
#
# We'll now perform basic operations on the DataFrame, denoted with comments.

# %%
# print the first and last 3 rows
prod.head(3)
# Out:
#    ProductID             Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 0          1  Adjustable Race       AR-5381         0                  0
# 1          2     Bearing Ball       BA-8327         0                  0
# 2          3  BB Ball Bearing       BE-2349         1                  0
#
#   Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  ...  \
# 0   NaN              1000           750           0.0        0.0  ...
# 1   NaN              1000           750           0.0        0.0  ...
# 2   NaN               800           600           0.0        0.0  ...
#
#   ProductLine Class Style  ProductSubcategoryID  ProductModelID  \
# 0         NaN   NaN   NaN                   NaN             NaN
# 1         NaN   NaN   NaN                   NaN             NaN
# 2         NaN   NaN   NaN                   NaN             NaN
#
#          SellStartDate SellEndDate DiscontinuedDate  \
# 0  2008-04-30 00:00:00         NaN              NaN
# 1  2008-04-30 00:00:00         NaN              NaN
# 2  2008-04-30 00:00:00         NaN              NaN
#
#                                   rowguid                   ModifiedDate
# 0  {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}  2014-02-08 10:01:36.827000000
# 1  {58AE3C20-4F3A-4749-A7D4-D568806CC537}  2014-02-08 10:01:36.827000000
# 2  {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}  2014-02-08 10:01:36.827000000
#
# [3 rows x 25 columns]

# %% [markdown]
# Notice that `.head()` is a method (denoted by parantheses), so it takes arguments.

# %% [markdown]
# **Class Question:**
# - What do you think changes if we pass a different number `head()` argument?
# - How would we print the last 5 rows?

# %%
# identify the shape (rows by columns)
rows, columns = prod.shape

# %% [markdown]
# Here we have 504 rows, and 25 columns. This is a tuple, so we can extract the parts using indexing:

# %%
# print the number of rows
print(f'There are {rows} rows')
print(f'There are {columns} columns')
# Out:
# There are 504 rows
# There are 25 columns

# %% [markdown]
# ## Using the index
# An [index](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Index.html) is an immutable ndarray implementing an ordered, sliceable set. The basic object storing axis labels for all pandas objects. Think of it as a 'row address' for your data frame (table). It is best practice to explicitly set the index of your dataframe, as these are commonly used as [primary keys](https://en.wikipedia.org/wiki/Primary_key) which can be used to [join](https://www.w3schools.com/sql/sql_join.asp) your dataframe to other dataframes.
#
# The dataframe can store different types (int, string, datetime), and when importing data will automatically assign a number to each row, starting at zero and counting up. You can overwrite this, which is what we are going to do.

# %%
# display the index as it sits (auto-generated upon import)
prod.index
# Out:
# RangeIndex(start=0, stop=504, step=1)

# %%
# note that our auto-generated index has no name
print(prod.index.name)
# Out:
# None

# %%
# Here we are looking at three columns;
# the one on the left is the index (automatically generated upon import by pandas)
# 'ProductID' is our PK (primary key) from our imported table. 'Name' is a data column.
# Notice that the generated index starts at zero and our PK starts at 1.
prod.head()[['ProductID', 'Name']]
# Out:
#    ProductID                   Name
# 0          1        Adjustable Race
# 1          2           Bearing Ball
# 2          3        BB Ball Bearing
# 3          4  Headset Ball Bearings
# 4        316                  Blade

# %%
# Setting the index overwrites the automatically generated index
# with our PK, which resided in the 'ProductID' column.
prod.set_index('ProductID', inplace=True)

# %%
# Note how our index property has changed as a result
prod.index
# Out:
# Int64Index([  1,   2,   3,   4, 316, 317, 318, 319, 320, 321,
#             ...
#             990, 991, 992, 993, 994, 995, 996, 997, 998, 999],
#            dtype='int64', name='ProductID', length=504)

# %%
# And our index has also inherited the name of our 'ProductID' column
prod.index.name
# Out:
# 'ProductID'

# %% [markdown]
# ## Column headers and datatypes

# %%
# print the columns
prod.columns
# Out:
# Index(['Name', 'ProductNumber', 'MakeFlag', 'FinishedGoodsFlag', 'Color',
#        'SafetyStockLevel', 'ReorderPoint', 'StandardCost', 'ListPrice', 'Size',
#        'SizeUnitMeasureCode', 'WeightUnitMeasureCode', 'Weight',
#        'DaysToManufacture', 'ProductLine', 'Class', 'Style',
#        'ProductSubcategoryID', 'ProductModelID', 'SellStartDate',
#        'SellEndDate', 'DiscontinuedDate', 'rowguid', 'ModifiedDate'],
#       dtype='object')

# %%
# examine the datatypes of the columns
# note that these were automatically inferred by pandas upon import!
prod.dtypes
# Out:
# Name                      object
# ProductNumber             object
# MakeFlag                   int64
# FinishedGoodsFlag          int64
# Color                     object
# SafetyStockLevel           int64
# ReorderPoint               int64
# StandardCost             float64
# ListPrice                float64
# Size                      object
# SizeUnitMeasureCode       object
# WeightUnitMeasureCode     object
# Weight                   float64
# DaysToManufacture          int64
# ProductLine               object
# Class                     object
# Style                     object
# ProductSubcategoryID     float64
# ProductModelID           float64
# SellStartDate             object
# SellEndDate               object
# DiscontinuedDate         float64
# rowguid                   object
# ModifiedDate              object
# dtype: object

# %% [markdown]
# **Class Question:** Why do datatypes matter? What operations could we perform on some datatypes that we could not on others? Note the importance of this in checking dataset integrity.

# %% [markdown]
# ## Selecting a Column
#
# We can select columns in two ways. Either we treat the column as an attribute of the DataFrame or we index the DataFrame for a specific element (in this case, the element is a column name).

# %%
# show the difference in data types by using single and double square brackets
prod['Name']
# Out:
# ProductID
# 1            Adjustable Race
# 2               Bearing Ball
# 3            BB Ball Bearing
# 4      Headset Ball Bearings
# 316                    Blade
#                ...
# 995        ML Bottom Bracket
# 996        HL Bottom Bracket
# 997       Road-750 Black, 44
# 998       Road-750 Black, 48
# 999       Road-750 Black, 52
# Name: Name, Length: 504, dtype: object

# %%
# select the Name column only, returned as a Series object

# %%
# select the Name column only, returned as a DataFrame object

# %%
# selecting > 1 column (must use double brackets!)
cols = ['Name', 'Class']
prod[cols]
# Out:
#                             Name Class
# ProductID
# 1                Adjustable Race   NaN
# 2                   Bearing Ball   NaN
# 3                BB Ball Bearing   NaN
# 4          Headset Ball Bearings   NaN
# 316                        Blade   NaN
# ...                          ...   ...
# 995            ML Bottom Bracket    M
# 996            HL Bottom Bracket    H
# 997           Road-750 Black, 44    L
# 998           Road-750 Black, 48    L
# 999           Road-750 Black, 52    L
#
# [504 rows x 2 columns]

# %%
prod[['Name', 'Class']]
# Out:
#                             Name Class
# ProductID
# 1                Adjustable Race   NaN
# 2                   Bearing Ball   NaN
# 3                BB Ball Bearing   NaN
# 4          Headset Ball Bearings   NaN
# 316                        Blade   NaN
# ...                          ...   ...
# 995            ML Bottom Bracket    M
# 996            HL Bottom Bracket    H
# 997           Road-750 Black, 44    L
# 998           Road-750 Black, 48    L
# 999           Road-750 Black, 52    L
#
# [504 rows x 2 columns]

# %% [markdown]
# **Class Question:** What if we wanted to select a column that has a space in it? Which method from the above two would we use? Why?

# %% [markdown]
# ## Renaming Columns
#
# Perhaps we want to rename our columns. There are a few options for doing this.
#
# Renaming **specific** columns by using a dictionary:

# %%
# rename one or more columns with a dictionary. Note: inplace=False will return a new dataframe,
# but leave the original dataframe untouched. Change this to True to modify the original dataframe.
prod.rename(columns={'Name': 'ProductName', 'ProductNumber': 'Number'}, inplace=True)

# %% [markdown]
# Renaming **ALL** columns with a new list of column names.
#
# Note that the `pd.DataFrame.columns` property can be cast to a `list` type. Originally, it's a `pd.core.indexes.base.Index` object:

# %%
print('My columns look like:\n', prod.columns)
print('\nAnd the type is:\n', type(prod.columns))
# Out:
# My columns look like:
#  Index(['ProductName', 'Number', 'MakeFlag', 'FinishedGoodsFlag', 'Color',
#        'SafetyStockLevel', 'ReorderPoint', 'StandardCost', 'ListPrice', 'Size',
#        'SizeUnitMeasureCode', 'WeightUnitMeasureCode', 'Weight',
#        'DaysToManufacture', 'ProductLine', 'Class', 'Style',
#        'ProductSubcategoryID', 'ProductModelID', 'SellStartDate',
#        'SellEndDate', 'DiscontinuedDate', 'rowguid', 'ModifiedDate'],
#       dtype='object')
#
# And the type is:
#  <class 'pandas.core.indexes.base.Index'>

# %% [markdown]
# We can explicitly cast these to a list object as such, by using the built-in `list()` function:

# %%
print('Now my columns look like:\n', list(prod.columns))
print('\nAnd are of type:\n', type(list(prod.columns)))
# Out:
# Now my columns look like:
#  ['ProductName', 'Number', 'MakeFlag', 'FinishedGoodsFlag', 'Color', 'SafetyStockLevel', 'ReorderPoint', 'StandardCost', 'ListPrice', 'Size', 'SizeUnitMeasureCode', 'WeightUnitMeasureCode', 'Weight', 'DaysToManufacture', 'ProductLine', 'Class', 'Style', 'ProductSubcategoryID', 'ProductModelID', 'SellStartDate', 'SellEndDate', 'DiscontinuedDate', 'rowguid', 'ModifiedDate']
#
# And are of type:
#  <class 'list'>

# %% [markdown]
# We can place these columns into a variable, `cols`:

# %%
# declare a list of strings - these strings will become the new column names
cols = list(prod.columns)
print(cols)
# Out:
# ['ProductName', 'Number', 'MakeFlag', 'FinishedGoodsFlag', 'Color', 'SafetyStockLevel', 'ReorderPoint', 'StandardCost', 'ListPrice', 'Size', 'SizeUnitMeasureCode', 'WeightUnitMeasureCode', 'Weight', 'DaysToManufacture', 'ProductLine', 'Class', 'Style', 'ProductSubcategoryID', 'ProductModelID', 'SellStartDate', 'SellEndDate', 'DiscontinuedDate', 'rowguid', 'ModifiedDate']

# %% [markdown]
# We can use list indexing to mutate the columns we want:

# %%
# overwrite one of the column names using list indexing
cols[0] = 'NewName'

# %%
prod.columns = cols

# %% [markdown]
# Finally, we can set the `pd.DataFrame.columns` property (this is a settable class property), to the new `cols` list, overwriting the existing columns header names:

# %%
# Note that our first column name has changed from 'Name' to 'NewName'
prod.head()
# Out:
#                          NewName   Number  MakeFlag  FinishedGoodsFlag Color  \
# ProductID
# 1                Adjustable Race  AR-5381         0                  0   NaN
# 2                   Bearing Ball  BA-8327         0                  0   NaN
# 3                BB Ball Bearing  BE-2349         1                  0   NaN
# 4          Headset Ball Bearings  BE-2908         0                  0   NaN
# 316                        Blade  BL-2036         1                  0   NaN
#
#            SafetyStockLevel  ReorderPoint  StandardCost  ListPrice Size  ...  \
# ProductID                                                                ...
# 1                      1000           750           0.0        0.0  NaN  ...
# 2                      1000           750           0.0        0.0  NaN  ...
# 3                       800           600           0.0        0.0  NaN  ...
# 4                       800           600           0.0        0.0  NaN  ...
# 316                     800           600           0.0        0.0  NaN  ...
#
#           ProductLine Class  Style  ProductSubcategoryID ProductModelID  \
# ProductID
# 1                 NaN   NaN    NaN                   NaN            NaN
# 2                 NaN   NaN    NaN                   NaN            NaN
# 3                 NaN   NaN    NaN                   NaN            NaN
# 4                 NaN   NaN    NaN                   NaN            NaN
# 316               NaN   NaN    NaN                   NaN            NaN
#
#                  SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 1          2008-04-30 00:00:00         NaN               NaN
# 2          2008-04-30 00:00:00         NaN               NaN
# 3          2008-04-30 00:00:00         NaN               NaN
# 4          2008-04-30 00:00:00         NaN               NaN
# 316        2008-04-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 1          {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2          {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3          {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 4          {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
# 316        {E73E9750-603B-4131-89F5-3DD15ED5FF80}
#
#                             ModifiedDate
# ProductID
# 1          2014-02-08 10:01:36.827000000
# 2          2014-02-08 10:01:36.827000000
# 3          2014-02-08 10:01:36.827000000
# 4          2014-02-08 10:01:36.827000000
# 316        2014-02-08 10:01:36.827000000
#
# [5 rows x 24 columns]

# %%
# display the final result of the 'NewName' column
# prod.head(3)[['NewName']]

# %% [markdown]
# ## Common Column Operations
#
# While this is non-comprehensive, these are a few key column-specific data checks.

# %% [markdown]
# **Descriptive statistics:**  the minimum, first quartile, median, third quartile, and maximum.
#
# (And more! The mean too.)

# %% [markdown]
# Five Number Summary (all assumes numeric data):
# - **Min:** The smallest value in the column
# - **Max:** The largest value in the column
# - **Quartile:** A quartile is one fourth of our data
#     - **First quartile:** This is the bottom most 25 percent
#     - **Median:** The middle value. (Line all values biggest to smallest - median is the middle!) Also the 50th percentile
#     - **Third quartile:** This the the top 75 percentile of our data

# %% [markdown]
# ![](https://www.mathsisfun.com/data/images/quartiles-a.svg)

# %%
# note - .describe() *default* only checks numeric datatypes
# show .describe() for the 'MakeFlag', 'SafetyStockLevel', 'StandardCost' fields.
prod.describe()
# Out:
#          MakeFlag  FinishedGoodsFlag  SafetyStockLevel  ReorderPoint  \
# count  504.000000         504.000000        504.000000    504.000000
# mean     0.474206           0.585317        535.150794    401.363095
# std      0.499830           0.493157        374.112954    280.584715
# min      0.000000           0.000000          4.000000      3.000000
# 25%      0.000000           0.000000        100.000000     75.000000
# 50%      0.000000           1.000000        500.000000    375.000000
# 75%      1.000000           1.000000       1000.000000    750.000000
# max      1.000000           1.000000       1000.000000    750.000000
#
#        StandardCost    ListPrice       Weight  DaysToManufacture  \
# count    504.000000   504.000000   205.000000         504.000000
# mean     258.602961   438.666250    74.069220           1.103175
# std      461.632808   773.602843   182.166588           1.492616
# min        0.000000     0.000000     2.120000           0.000000
# 25%        0.000000     0.000000     2.880000           0.000000
# 50%       23.372200    49.990000    17.900000           1.000000
# 75%      317.075825   564.990000    27.350000           1.000000
# max     2171.294200  3578.270000  1050.000000           4.000000
#
#        ProductSubcategoryID  ProductModelID  DiscontinuedDate
# count            295.000000      295.000000               0.0
# mean              12.294915       37.444068               NaN
# std                9.860135       34.025442               NaN
# min                1.000000        1.000000               NaN
# 25%                2.000000       11.000000               NaN
# 50%               12.000000       26.000000               NaN
# 75%               17.000000       48.500000               NaN
# max               37.000000      128.000000               NaN

# %% [markdown]
# **Value Counts:** `pd.Series.value_counts()` count the occurrence of each value within our series.

# %%
# show the most popular product colors (aggregated by count, descending by default)
prod['Color'].value_counts()
# Out:
# Black           93
# Silver          43
# Red             38
# Yellow          36
# Blue            26
# Multi            8
# Silver/Black     7
# White            4
# Grey             1
# Name: Color, dtype: int64

# %% [markdown]
# **Unique values:** Determine the number of distinct values within a given series.

# %%
# What are the unique colors for the products?
prod['Color'].unique()
# Out:
# array([nan, 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow',
#        'Grey', 'Silver/Black'], dtype=object)

# %%
# how many distinct colors are there?
len(prod['Color'].unique())
# Out:
# 10

# %%
prod['Color'].nunique()
# Out:
# 9

# %%
# We can also include nulls with .nunique() as such:
prod['Color'].nunique(dropna=False)
# Out:
# 10

# %% [markdown]
# ## Filtering on a Single Condition
#
# Filtering and sorting are key processes that allow us to drill into the 'nitty gritty' and cross sections of our dataset.
#
# To filter, we use a process called **Boolean Filtering**, wherein we define a Boolean condition, and use that Boolean condition to filer on our DataFrame.

# %% [markdown]
# Recall: our given dataset has a column `Color`. Let's see if we can find all products that are `Black`. Let's take a look at the first 10 rows of the dataframe to see how it looks as-is:

# %%
# show the first 10 rows of the 'Color' column
prod['Color'].head(10)
# Out:
# ProductID
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 316       NaN
# 317     Black
# 318     Black
# 319     Black
# 320    Silver
# 321    Silver
# Name: Color, dtype: object

# %% [markdown]
# By applying a `boolean mask` to this dataframe, `== 'Black'`, we can get the following:

# %%
# set the previous output to == Black
prod['Color'].head(10) == 'Black'
# Out:
# ProductID
# 1      False
# 2      False
# 3      False
# 4      False
# 316    False
# 317     True
# 318     True
# 319     True
# 320    False
# 321    False
# Name: Color, dtype: bool

# %% [markdown]
# Now we can use that 'mask' from above, and apply it to our full dataframe. Every time we have a `True` in a row, we return the row. If we have a `False` in that row, we do not return it. The result is a dataframe that only has rows where `Color` is `Black`:

# %%
# show the full prod DataFrame where Color is Black
cond_1 = prod['Color'] == 'Black'
prod[cond_1]
# Out:
#                              NewName      Number  MakeFlag  FinishedGoodsFlag  \
# ProductID
# 317                      LL Crankarm     CA-5965         0                  0
# 318                      ML Crankarm     CA-6738         0                  0
# 319                      HL Crankarm     CA-7457         0                  0
# 322                        Chainring     CR-7833         0                  0
# 680        HL Road Frame - Black, 58  FR-R92B-58         1                  1
# ...                              ...         ...       ...                ...
# 992           Mountain-500 Black, 48  BK-M18B-48         1                  1
# 993           Mountain-500 Black, 52  BK-M18B-52         1                  1
# 997               Road-750 Black, 44  BK-R19B-44         1                  1
# 998               Road-750 Black, 48  BK-R19B-48         1                  1
# 999               Road-750 Black, 52  BK-R19B-52         1                  1
#
#            Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  \
# ProductID
# 317        Black               500           375        0.0000       0.00
# 318        Black               500           375        0.0000       0.00
# 319        Black               500           375        0.0000       0.00
# 322        Black              1000           750        0.0000       0.00
# 680        Black               500           375     1059.3100    1431.50
# ...          ...               ...           ...           ...        ...
# 992        Black               100            75      294.5797     539.99
# 993        Black               100            75      294.5797     539.99
# 997        Black               100            75      343.6496     539.99
# 998        Black               100            75      343.6496     539.99
# 999        Black               100            75      343.6496     539.99
#
#           Size  ... ProductLine Class  Style  ProductSubcategoryID  \
# ProductID       ...
# 317        NaN  ...         NaN    L     NaN                   NaN
# 318        NaN  ...         NaN    M     NaN                   NaN
# 319        NaN  ...         NaN   NaN    NaN                   NaN
# 322        NaN  ...         NaN   NaN    NaN                   NaN
# 680         58  ...          R     H      U                   14.0
# ...        ...  ...         ...   ...    ...                   ...
# 992         48  ...          M     L      U                    1.0
# 993         52  ...          M     L      U                    1.0
# 997         44  ...          R     L      U                    2.0
# 998         48  ...          R     L      U                    2.0
# 999         52  ...          R     L      U                    2.0
#
#           ProductModelID        SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 317                  NaN  2008-04-30 00:00:00         NaN               NaN
# 318                  NaN  2008-04-30 00:00:00         NaN               NaN
# 319                  NaN  2008-04-30 00:00:00         NaN               NaN
# 322                  NaN  2008-04-30 00:00:00         NaN               NaN
# 680                  6.0  2008-04-30 00:00:00         NaN               NaN
# ...                  ...                  ...         ...               ...
# 992                 23.0  2013-05-30 00:00:00         NaN               NaN
# 993                 23.0  2013-05-30 00:00:00         NaN               NaN
# 997                 31.0  2013-05-30 00:00:00         NaN               NaN
# 998                 31.0  2013-05-30 00:00:00         NaN               NaN
# 999                 31.0  2013-05-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 317        {3C9D10B7-A6B2-4774-9963-C19DCEE72FEA}
# 318        {EABB9A92-FA07-4EAB-8955-F0517B4A4CA7}
# 319        {7D3FD384-4F29-484B-86FA-4206E276FE58}
# 322        {F0AC2C4D-1A1F-4E3C-B4D9-68AEA0EC1CE4}
# 680        {43DD68D6-14A4-461F-9069-55309D90EA7E}
# ...                                           ...
# 992        {75752E26-A3B6-4264-9B06-F23A4FBDC5A7}
# 993        {69EE3B55-E142-4E4F-AED8-AF02978FBE87}
# 997        {44CE4802-409F-43AB-9B27-CA53421805BE}
# 998        {3DE9A212-1D49-40B6-B10A-F564D981DBDE}
# 999        {AE638923-2B67-4679-B90E-ABBAB17DCA31}
#
#                             ModifiedDate
# ProductID
# 317        2014-02-08 10:01:36.827000000
# 318        2014-02-08 10:01:36.827000000
# 319        2014-02-08 10:01:36.827000000
# 322        2014-02-08 10:01:36.827000000
# 680        2014-02-08 10:01:36.827000000
# ...                                  ...
# 992        2014-02-08 10:01:36.827000000
# 993        2014-02-08 10:01:36.827000000
# 997        2014-02-08 10:01:36.827000000
# 998        2014-02-08 10:01:36.827000000
# 999        2014-02-08 10:01:36.827000000
#
# [93 rows x 24 columns]

# %% [markdown]
# Let's calculate the **average ListPrice** for the **salable products**.

# %% [markdown]
# > Think: What are the component parts of this problem?

# %%
# First, we need to get salable items. 
# Use your data dictionary from the beginning of this lesson. 
cond_1 = prod['FinishedGoodsFlag'] == 1
salable = prod[cond_1]
salable.head(3)
# Out:
#                              NewName      Number  MakeFlag  FinishedGoodsFlag  \
# ProductID
# 680        HL Road Frame - Black, 58  FR-R92B-58         1                  1
# 706          HL Road Frame - Red, 58  FR-R92R-58         1                  1
# 707            Sport-100 Helmet, Red   HL-U509-R         0                  1
#
#            Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  \
# ProductID
# 680        Black               500           375     1059.3100    1431.50
# 706          Red               500           375     1059.3100    1431.50
# 707          Red                 4             3       13.0863      34.99
#
#           Size  ... ProductLine Class  Style  ProductSubcategoryID  \
# ProductID       ...
# 680         58  ...          R     H      U                   14.0
# 706         58  ...          R     H      U                   14.0
# 707        NaN  ...          S    NaN    NaN                  31.0
#
#           ProductModelID        SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 680                  6.0  2008-04-30 00:00:00         NaN               NaN
# 706                  6.0  2008-04-30 00:00:00         NaN               NaN
# 707                 33.0  2011-05-31 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 680        {43DD68D6-14A4-461F-9069-55309D90EA7E}
# 706        {9540FF17-2712-4C90-A3D1-8CE5568B2462}
# 707        {2E1EF41A-C08A-4FF6-8ADA-BDE58B64A712}
#
#                             ModifiedDate
# ProductID
# 680        2014-02-08 10:01:36.827000000
# 706        2014-02-08 10:01:36.827000000
# 707        2014-02-08 10:01:36.827000000
#
# [3 rows x 24 columns]

# %% [markdown]
# Now, we need to find average list price of those above items. Let's just get the 'ListPrice' column for starters.

# %%
salable['ListPrice'].mean()
# Out:
# 744.595220338982

# %% [markdown]
# To get the average of that column, just take `.mean()`

# %% [markdown]
# We can take a shortcut and just use `.describe()` here:

# %%
salable.describe()
# Out:
#          MakeFlag  FinishedGoodsFlag  SafetyStockLevel  ReorderPoint  \
# count  295.000000              295.0        295.000000    295.000000
# mean     0.718644                1.0        277.681356    208.261017
# std      0.450425                0.0        219.959165    164.969374
# min      0.000000                1.0          4.000000      3.000000
# 25%      0.000000                1.0        100.000000     75.000000
# 50%      1.000000                1.0        100.000000     75.000000
# 75%      1.000000                1.0        500.000000    375.000000
# max      1.000000                1.0        500.000000    375.000000
#
#        StandardCost    ListPrice       Weight  DaysToManufacture  \
# count    295.000000   295.000000   198.000000         295.000000
# mean     438.220347   744.595220    61.334293           1.793220
# std      534.895607   892.563172   171.964576           1.606096
# min        0.856500     2.290000     2.120000           0.000000
# 25%       35.959600    66.745000     2.850000           1.000000
# 50%      199.851900   337.220000    17.385000           1.000000
# 75%      650.418250  1100.240000    26.402500           4.000000
# max     2171.294200  3578.270000  1050.000000           4.000000
#
#        ProductSubcategoryID  ProductModelID  DiscontinuedDate
# count            295.000000      295.000000               0.0
# mean              12.294915       37.444068               NaN
# std                9.860135       34.025442               NaN
# min                1.000000        1.000000               NaN
# 25%                2.000000       11.000000               NaN
# 50%               12.000000       26.000000               NaN
# 75%               17.000000       48.500000               NaN
# max               37.000000      128.000000               NaN

# %% [markdown]
# **Sneak peek**: Another handy trick is to use `.hist()` to get a distribution of a continuous variable - in this case, `ListPrice`. We'll cover this more in future lessons:

# %%
salable['ListPrice'].hist(grid=False, bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Filtering on Multiple Conditions
#
# Here, we will filter on _multiple conditions_. Before, we filtered on rows where Color was Black. We also filtered where FinishedGoodsFlag was equal to 1. Let's see what happens when we filter on *both* simultaneously.
#
# The format for multiple conditions is:
#
# `df[ (df['col1'] == value1) & (df['col2'] == value2) ]`
#
# Or, more simply:
#
# `df[ (CONDITION 1) & (CONDITION 2) ]`
#
# Which eventually may evaluate to something like:
#
# `df[ True & False ]`
#
# ...on a row-by-row basis. If the end result is `False`, the row is omitted.
#
# _Don't forget parentheses in your conditions!_ This is a common mistake.

# %%
# Let's look at a table where Color is Black, AND FinishedGoodsFlag is 1
cond1 = prod['Color'] == 'Black'
cond2 = prod['FinishedGoodsFlag'] == 1

prod[cond1 & cond2]
# Out:
#                              NewName      Number  MakeFlag  FinishedGoodsFlag  \
# ProductID
# 680        HL Road Frame - Black, 58  FR-R92B-58         1                  1
# 708          Sport-100 Helmet, Black     HL-U509         0                  1
# 722        LL Road Frame - Black, 58  FR-R38B-58         1                  1
# 723        LL Road Frame - Black, 60  FR-R38B-60         1                  1
# 724        LL Road Frame - Black, 62  FR-R38B-62         1                  1
# ...                              ...         ...       ...                ...
# 992           Mountain-500 Black, 48  BK-M18B-48         1                  1
# 993           Mountain-500 Black, 52  BK-M18B-52         1                  1
# 997               Road-750 Black, 44  BK-R19B-44         1                  1
# 998               Road-750 Black, 48  BK-R19B-48         1                  1
# 999               Road-750 Black, 52  BK-R19B-52         1                  1
#
#            Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  \
# ProductID
# 680        Black               500           375     1059.3100    1431.50
# 708        Black                 4             3       13.0863      34.99
# 722        Black               500           375      204.6251     337.22
# 723        Black               500           375      204.6251     337.22
# 724        Black               500           375      204.6251     337.22
# ...          ...               ...           ...           ...        ...
# 992        Black               100            75      294.5797     539.99
# 993        Black               100            75      294.5797     539.99
# 997        Black               100            75      343.6496     539.99
# 998        Black               100            75      343.6496     539.99
# 999        Black               100            75      343.6496     539.99
#
#           Size  ... ProductLine Class  Style  ProductSubcategoryID  \
# ProductID       ...
# 680         58  ...          R     H      U                   14.0
# 708        NaN  ...          S    NaN    NaN                  31.0
# 722         58  ...          R     L      U                   14.0
# 723         60  ...          R     L      U                   14.0
# 724         62  ...          R     L      U                   14.0
# ...        ...  ...         ...   ...    ...                   ...
# 992         48  ...          M     L      U                    1.0
# 993         52  ...          M     L      U                    1.0
# 997         44  ...          R     L      U                    2.0
# 998         48  ...          R     L      U                    2.0
# 999         52  ...          R     L      U                    2.0
#
#           ProductModelID        SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 680                  6.0  2008-04-30 00:00:00         NaN               NaN
# 708                 33.0  2011-05-31 00:00:00         NaN               NaN
# 722                  9.0  2011-05-31 00:00:00         NaN               NaN
# 723                  9.0  2011-05-31 00:00:00         NaN               NaN
# 724                  9.0  2011-05-31 00:00:00         NaN               NaN
# ...                  ...                  ...         ...               ...
# 992                 23.0  2013-05-30 00:00:00         NaN               NaN
# 993                 23.0  2013-05-30 00:00:00         NaN               NaN
# 997                 31.0  2013-05-30 00:00:00         NaN               NaN
# 998                 31.0  2013-05-30 00:00:00         NaN               NaN
# 999                 31.0  2013-05-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 680        {43DD68D6-14A4-461F-9069-55309D90EA7E}
# 708        {A25A44FB-C2DE-4268-958F-110B8D7621E2}
# 722        {2140F256-F705-4D67-975D-32DE03265838}
# 723        {AA95E2A5-E7C4-4B74-B1EA-B52EE3B51537}
# 724        {5247BE33-50BF-4527-8A30-A39AAE500A8E}
# ...                                           ...
# 992        {75752E26-A3B6-4264-9B06-F23A4FBDC5A7}
# 993        {69EE3B55-E142-4E4F-AED8-AF02978FBE87}
# 997        {44CE4802-409F-43AB-9B27-CA53421805BE}
# 998        {3DE9A212-1D49-40B6-B10A-F564D981DBDE}
# 999        {AE638923-2B67-4679-B90E-ABBAB17DCA31}
#
#                             ModifiedDate
# ProductID
# 680        2014-02-08 10:01:36.827000000
# 708        2014-02-08 10:01:36.827000000
# 722        2014-02-08 10:01:36.827000000
# 723        2014-02-08 10:01:36.827000000
# 724        2014-02-08 10:01:36.827000000
# ...                                  ...
# 992        2014-02-08 10:01:36.827000000
# 993        2014-02-08 10:01:36.827000000
# 997        2014-02-08 10:01:36.827000000
# 998        2014-02-08 10:01:36.827000000
# 999        2014-02-08 10:01:36.827000000
#
# [89 rows x 24 columns]

# %%
prod[cond1 | cond2]
# Out:
#                              NewName      Number  MakeFlag  FinishedGoodsFlag  \
# ProductID
# 317                      LL Crankarm     CA-5965         0                  0
# 318                      ML Crankarm     CA-6738         0                  0
# 319                      HL Crankarm     CA-7457         0                  0
# 322                        Chainring     CR-7833         0                  0
# 680        HL Road Frame - Black, 58  FR-R92B-58         1                  1
# ...                              ...         ...       ...                ...
# 995                ML Bottom Bracket     BB-8107         1                  1
# 996                HL Bottom Bracket     BB-9108         1                  1
# 997               Road-750 Black, 44  BK-R19B-44         1                  1
# 998               Road-750 Black, 48  BK-R19B-48         1                  1
# 999               Road-750 Black, 52  BK-R19B-52         1                  1
#
#            Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  \
# ProductID
# 317        Black               500           375        0.0000       0.00
# 318        Black               500           375        0.0000       0.00
# 319        Black               500           375        0.0000       0.00
# 322        Black              1000           750        0.0000       0.00
# 680        Black               500           375     1059.3100    1431.50
# ...          ...               ...           ...           ...        ...
# 995          NaN               500           375       44.9506     101.24
# 996          NaN               500           375       53.9416     121.49
# 997        Black               100            75      343.6496     539.99
# 998        Black               100            75      343.6496     539.99
# 999        Black               100            75      343.6496     539.99
#
#           Size  ... ProductLine Class  Style  ProductSubcategoryID  \
# ProductID       ...
# 317        NaN  ...         NaN    L     NaN                   NaN
# 318        NaN  ...         NaN    M     NaN                   NaN
# 319        NaN  ...         NaN   NaN    NaN                   NaN
# 322        NaN  ...         NaN   NaN    NaN                   NaN
# 680         58  ...          R     H      U                   14.0
# ...        ...  ...         ...   ...    ...                   ...
# 995        NaN  ...         NaN    M     NaN                   5.0
# 996        NaN  ...         NaN    H     NaN                   5.0
# 997         44  ...          R     L      U                    2.0
# 998         48  ...          R     L      U                    2.0
# 999         52  ...          R     L      U                    2.0
#
#           ProductModelID        SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 317                  NaN  2008-04-30 00:00:00         NaN               NaN
# 318                  NaN  2008-04-30 00:00:00         NaN               NaN
# 319                  NaN  2008-04-30 00:00:00         NaN               NaN
# 322                  NaN  2008-04-30 00:00:00         NaN               NaN
# 680                  6.0  2008-04-30 00:00:00         NaN               NaN
# ...                  ...                  ...         ...               ...
# 995                 96.0  2013-05-30 00:00:00         NaN               NaN
# 996                 97.0  2013-05-30 00:00:00         NaN               NaN
# 997                 31.0  2013-05-30 00:00:00         NaN               NaN
# 998                 31.0  2013-05-30 00:00:00         NaN               NaN
# 999                 31.0  2013-05-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 317        {3C9D10B7-A6B2-4774-9963-C19DCEE72FEA}
# 318        {EABB9A92-FA07-4EAB-8955-F0517B4A4CA7}
# 319        {7D3FD384-4F29-484B-86FA-4206E276FE58}
# 322        {F0AC2C4D-1A1F-4E3C-B4D9-68AEA0EC1CE4}
# 680        {43DD68D6-14A4-461F-9069-55309D90EA7E}
# ...                                           ...
# 995        {71AB847F-D091-42D6-B735-7B0C2D82FC84}
# 996        {230C47C5-08B2-4CE3-B706-69C0BDD62965}
# 997        {44CE4802-409F-43AB-9B27-CA53421805BE}
# 998        {3DE9A212-1D49-40B6-B10A-F564D981DBDE}
# 999        {AE638923-2B67-4679-B90E-ABBAB17DCA31}
#
#                             ModifiedDate
# ProductID
# 317        2014-02-08 10:01:36.827000000
# 318        2014-02-08 10:01:36.827000000
# 319        2014-02-08 10:01:36.827000000
# 322        2014-02-08 10:01:36.827000000
# 680        2014-02-08 10:01:36.827000000
# ...                                  ...
# 995        2014-02-08 10:01:36.827000000
# 996        2014-02-08 10:01:36.827000000
# 997        2014-02-08 10:01:36.827000000
# 998        2014-02-08 10:01:36.827000000
# 999        2014-02-08 10:01:36.827000000
#
# [299 rows x 24 columns]

# %%
# Here we have an example of a list price of greater than 50, 
# OR a product size that is not equal to 'XL'
cond1 = prod['ListPrice'] > 50
cond2 = prod['Size'] != 'XL'

prod[cond1 | cond2]
# Out:
#                          NewName      Number  MakeFlag  FinishedGoodsFlag  \
# ProductID
# 1                Adjustable Race     AR-5381         0                  0
# 2                   Bearing Ball     BA-8327         0                  0
# 3                BB Ball Bearing     BE-2349         1                  0
# 4          Headset Ball Bearings     BE-2908         0                  0
# 316                        Blade     BL-2036         1                  0
# ...                          ...         ...       ...                ...
# 995            ML Bottom Bracket     BB-8107         1                  1
# 996            HL Bottom Bracket     BB-9108         1                  1
# 997           Road-750 Black, 44  BK-R19B-44         1                  1
# 998           Road-750 Black, 48  BK-R19B-48         1                  1
# 999           Road-750 Black, 52  BK-R19B-52         1                  1
#
#            Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  \
# ProductID
# 1            NaN              1000           750        0.0000       0.00
# 2            NaN              1000           750        0.0000       0.00
# 3            NaN               800           600        0.0000       0.00
# 4            NaN               800           600        0.0000       0.00
# 316          NaN               800           600        0.0000       0.00
# ...          ...               ...           ...           ...        ...
# 995          NaN               500           375       44.9506     101.24
# 996          NaN               500           375       53.9416     121.49
# 997        Black               100            75      343.6496     539.99
# 998        Black               100            75      343.6496     539.99
# 999        Black               100            75      343.6496     539.99
#
#           Size  ... ProductLine Class  Style  ProductSubcategoryID  \
# ProductID       ...
# 1          NaN  ...         NaN   NaN    NaN                   NaN
# 2          NaN  ...         NaN   NaN    NaN                   NaN
# 3          NaN  ...         NaN   NaN    NaN                   NaN
# 4          NaN  ...         NaN   NaN    NaN                   NaN
# 316        NaN  ...         NaN   NaN    NaN                   NaN
# ...        ...  ...         ...   ...    ...                   ...
# 995        NaN  ...         NaN    M     NaN                   5.0
# 996        NaN  ...         NaN    H     NaN                   5.0
# 997         44  ...          R     L      U                    2.0
# 998         48  ...          R     L      U                    2.0
# 999         52  ...          R     L      U                    2.0
#
#           ProductModelID        SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 1                    NaN  2008-04-30 00:00:00         NaN               NaN
# 2                    NaN  2008-04-30 00:00:00         NaN               NaN
# 3                    NaN  2008-04-30 00:00:00         NaN               NaN
# 4                    NaN  2008-04-30 00:00:00         NaN               NaN
# 316                  NaN  2008-04-30 00:00:00         NaN               NaN
# ...                  ...                  ...         ...               ...
# 995                 96.0  2013-05-30 00:00:00         NaN               NaN
# 996                 97.0  2013-05-30 00:00:00         NaN               NaN
# 997                 31.0  2013-05-30 00:00:00         NaN               NaN
# 998                 31.0  2013-05-30 00:00:00         NaN               NaN
# 999                 31.0  2013-05-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 1          {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2          {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3          {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 4          {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
# 316        {E73E9750-603B-4131-89F5-3DD15ED5FF80}
# ...                                           ...
# 995        {71AB847F-D091-42D6-B735-7B0C2D82FC84}
# 996        {230C47C5-08B2-4CE3-B706-69C0BDD62965}
# 997        {44CE4802-409F-43AB-9B27-CA53421805BE}
# 998        {3DE9A212-1D49-40B6-B10A-F564D981DBDE}
# 999        {AE638923-2B67-4679-B90E-ABBAB17DCA31}
#
#                             ModifiedDate
# ProductID
# 1          2014-02-08 10:01:36.827000000
# 2          2014-02-08 10:01:36.827000000
# 3          2014-02-08 10:01:36.827000000
# 4          2014-02-08 10:01:36.827000000
# 316        2014-02-08 10:01:36.827000000
# ...                                  ...
# 995        2014-02-08 10:01:36.827000000
# 996        2014-02-08 10:01:36.827000000
# 997        2014-02-08 10:01:36.827000000
# 998        2014-02-08 10:01:36.827000000
# 999        2014-02-08 10:01:36.827000000
#
# [503 rows x 24 columns]

# %% [markdown]
# ## Sorting
#
# We can sort one column of our DataFrame as well.

# %%
# let's sort by standard cost, 
prod.sort_values(by='ListPrice', ascending=False).head()
# Out:
#                     NewName      Number  MakeFlag  FinishedGoodsFlag Color  \
# ProductID
# 752        Road-150 Red, 52  BK-R93R-52         1                  1   Red
# 750        Road-150 Red, 44  BK-R93R-44         1                  1   Red
# 753        Road-150 Red, 56  BK-R93R-56         1                  1   Red
# 751        Road-150 Red, 48  BK-R93R-48         1                  1   Red
# 749        Road-150 Red, 62  BK-R93R-62         1                  1   Red
#
#            SafetyStockLevel  ReorderPoint  StandardCost  ListPrice Size  ...  \
# ProductID                                                                ...
# 752                     100            75     2171.2942    3578.27   52  ...
# 750                     100            75     2171.2942    3578.27   44  ...
# 753                     100            75     2171.2942    3578.27   56  ...
# 751                     100            75     2171.2942    3578.27   48  ...
# 749                     100            75     2171.2942    3578.27   62  ...
#
#           ProductLine Class  Style  ProductSubcategoryID ProductModelID  \
# ProductID
# 752                R     H      U                    2.0           25.0
# 750                R     H      U                    2.0           25.0
# 753                R     H      U                    2.0           25.0
# 751                R     H      U                    2.0           25.0
# 749                R     H      U                    2.0           25.0
#
#                  SellStartDate          SellEndDate  DiscontinuedDate  \
# ProductID
# 752        2011-05-31 00:00:00  2012-05-29 00:00:00               NaN
# 750        2011-05-31 00:00:00  2012-05-29 00:00:00               NaN
# 753        2011-05-31 00:00:00  2012-05-29 00:00:00               NaN
# 751        2011-05-31 00:00:00  2012-05-29 00:00:00               NaN
# 749        2011-05-31 00:00:00  2012-05-29 00:00:00               NaN
#
#                                           rowguid  \
# ProductID
# 752        {5E085BA0-3CD5-487F-85BB-79ED1C701F23}
# 750        {C19E1136-5DA4-4B40-8758-54A85D7EA494}
# 753        {30819B88-F0D3-4E7A-8105-19F6FAC2CEFB}
# 751        {D10B7CC1-455E-435B-A08F-EC5B1C5776E9}
# 749        {BC621E1F-2553-4FDC-B22E-5E44A9003569}
#
#                             ModifiedDate
# ProductID
# 752        2014-02-08 10:01:36.827000000
# 750        2014-02-08 10:01:36.827000000
# 753        2014-02-08 10:01:36.827000000
# 751        2014-02-08 10:01:36.827000000
# 749        2014-02-08 10:01:36.827000000
#
# [5 rows x 24 columns]

# %% [markdown]
# This one is a little more advanced, but it demonstrates a few things:
# - Conversion of a `numpy.ndarray` object (return type of `pd.Series.unique()`) into a `pd.Series` object
# - `pd.Series.sort_values` with the `by=` kwarg omitted (if only one column is the operand, `by=` doesn't need specified
# - Alphabetical sort of a string field, `ascending=True` means A->Z
# - Inclusion of nulls, `NaN` in a string field (versus omission with a float/int as prior example)

# %%
pd.Series(prod['Color'].unique()).sort_values()
# Out:
# 1           Black
# 5            Blue
# 8            Grey
# 6           Multi
# 3             Red
# 2          Silver
# 9    Silver/Black
# 4           White
# 7          Yellow
# 0             NaN
# dtype: object

# %% [markdown]
# ## Independent Exercises
#
# Do your best to complete the following prompts. Don't hesitate to look at code we wrote together!

# %% [markdown]
# Print the first 4 rows of the whole DataFrame.

# %%
# your answer here
prod.head(4)
# Out:
#                          NewName   Number  MakeFlag  FinishedGoodsFlag Color  \
# ProductID
# 1                Adjustable Race  AR-5381         0                  0   NaN
# 2                   Bearing Ball  BA-8327         0                  0   NaN
# 3                BB Ball Bearing  BE-2349         1                  0   NaN
# 4          Headset Ball Bearings  BE-2908         0                  0   NaN
#
#            SafetyStockLevel  ReorderPoint  StandardCost  ListPrice Size  ...  \
# ProductID                                                                ...
# 1                      1000           750           0.0        0.0  NaN  ...
# 2                      1000           750           0.0        0.0  NaN  ...
# 3                       800           600           0.0        0.0  NaN  ...
# 4                       800           600           0.0        0.0  NaN  ...
#
#           ProductLine Class  Style  ProductSubcategoryID ProductModelID  \
# ProductID
# 1                 NaN   NaN    NaN                   NaN            NaN
# 2                 NaN   NaN    NaN                   NaN            NaN
# 3                 NaN   NaN    NaN                   NaN            NaN
# 4                 NaN   NaN    NaN                   NaN            NaN
#
#                  SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 1          2008-04-30 00:00:00         NaN               NaN
# 2          2008-04-30 00:00:00         NaN               NaN
# 3          2008-04-30 00:00:00         NaN               NaN
# 4          2008-04-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 1          {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2          {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3          {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 4          {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
#
#                             ModifiedDate
# ProductID
# 1          2014-02-08 10:01:36.827000000
# 2          2014-02-08 10:01:36.827000000
# 3          2014-02-08 10:01:36.827000000
# 4          2014-02-08 10:01:36.827000000
#
# [4 rows x 24 columns]

# %% [markdown]
# How many rows are in the dataframe? Return the answer as an int.

# %%
# your answer here
rows , columns = prod.shape
print(rows)
# Out:
# 504

# %% [markdown]
# How many columns? Retrun the answer as an int.

# %%
# your answer here

#print(columns)
prod.shape[1]
# Out:
# 24

# %% [markdown]
# How many different product lines are there?

# %%
# your answer here
prod['ProductLine'].nunique()
# Out:
# 4

# %% [markdown]
# What are the values of these product lines?

# %%
# your answer here
prod['ProductLine'].unique()
# Out:
# array([nan, 'R ', 'S ', 'M ', 'T '], dtype=object)

# %% [markdown]
# Do the number of values for the product lines match the number you have using `.nunique()`? Why or why not?

# %%
# your answer here
# no it doesnt match as there are product lines which dont have values i.e Nan

# %% [markdown]
# Take the output from your previous answer (using `.unique()`). Select the label corresponding to the `Road` product line using list indexing notation. How many characters are in this string?

# %%
# your answer here
len(prod['ProductLine'].unique()[1])
# Out:
# 2

# %% [markdown]
# Do you notice anything odd about this?

# %%
# your answer here

# %% [markdown]
# How many products are there for the `Road` product line? Don't forget what you just worked on above! Return your answer as an int.

# %%
# your answer here
cond1 = prod['ProductLine'] == 'R '
prod[cond1].shape
# Out:
# (100, 24)

# %% [markdown]
# How many products are there in the `Women's` `Mountain` category? Return your answer as an int. _Hint: Use the data dictionary above!_

# %%
# your answer here
cond1 = prod['Style'] == 'W '
cond2 = prod['ProductLine'] == 'M '

prod[cond1 & cond2].shape
# Out:
# (11, 24)

# %% [markdown]
# **Challenge:** What are the top 3 _most expensive list price_ product that are either in the `Women's` `Mountain` category, _OR_ `Silver` in `Color`? Return your answer as a DataFrame object, with the `ProductID` index, `NewName` relabeled as `Name`, and `ListPrice` columns. Perform the statement in one execution, and do not mutate the source DataFrame.

# %%
# your answer here
cond1 = prod['Style'] == 'W '
cond2 = prod['ProductLine'] == 'M '
conda = cond1 & cond2

cond3 = prod['Color'] == 'Silver'


prod[conda | cond3].rename(columns = {'NewName':'Name'} ).sort_values(by = 'ListPrice',ascending= False)
# Out:
#                                        Name      Number  MakeFlag  \
# ProductID
# 774                 Mountain-100 Silver, 48  BK-M82S-48         1
# 771                 Mountain-100 Silver, 38  BK-M82S-38         1
# 772                 Mountain-100 Silver, 42  BK-M82S-42         1
# 773                 Mountain-100 Silver, 44  BK-M82S-44         1
# 779                 Mountain-200 Silver, 38  BK-M68S-38         1
# 781                 Mountain-200 Silver, 46  BK-M68S-46         1
# 780                 Mountain-200 Silver, 42  BK-M68S-42         1
# 739          HL Mountain Frame - Silver, 42  FR-M94S-42         1
# 740          HL Mountain Frame - Silver, 44  FR-M94S-44         1
# 741          HL Mountain Frame - Silver, 48  FR-M94S-52         1
# 742          HL Mountain Frame - Silver, 46  FR-M94S-46         1
# 748          HL Mountain Frame - Silver, 38  FR-M94S-38         1
# 980               Mountain-400-W Silver, 38  BK-M38S-38         1
# 981               Mountain-400-W Silver, 40  BK-M38S-40         1
# 982               Mountain-400-W Silver, 42  BK-M38S-42         1
# 983               Mountain-400-W Silver, 46  BK-M38S-46         1
# 988                 Mountain-500 Silver, 52  BK-M18S-52         1
# 984                 Mountain-500 Silver, 40  BK-M18S-40         1
# 985                 Mountain-500 Silver, 42  BK-M18S-42         1
# 986                 Mountain-500 Silver, 44  BK-M18S-44         1
# 987                 Mountain-500 Silver, 48  BK-M18S-48         1
# 942        ML Mountain Frame-W - Silver, 38  FR-M63S-38         1
# 904        ML Mountain Frame-W - Silver, 40  FR-M63S-40         1
# 905        ML Mountain Frame-W - Silver, 42  FR-M63S-42         1
# 906        ML Mountain Frame-W - Silver, 46  FR-M63S-46         1
# 919          LL Mountain Frame - Silver, 48  FR-M21S-48         1
# 944          LL Mountain Frame - Silver, 40  FR-M21S-40         1
# 920          LL Mountain Frame - Silver, 52  FR-M21S-52         1
# 917          LL Mountain Frame - Silver, 42  FR-M21S-42         1
# 918          LL Mountain Frame - Silver, 44  FR-M21S-44         1
# 894                         Rear Derailleur     RD-2308         1
# 907                             Rear Brakes     RB-9231         0
# 948                            Front Brakes     FB-9873         0
# 945                        Front Derailleur     FD-2342         1
# 869              Women's Mountain Shorts, L   SH-W890-L         0
# 868              Women's Mountain Shorts, M   SH-W890-M         0
# 867              Women's Mountain Shorts, S   SH-W890-S         0
# 880                 Hydration Pack - 70 oz.  HY-1023-70         0
# 952                                   Chain     CH-0234         0
# 321                           Chainring Nut     CN-6137         0
# 679                    Rear Derailleur Cage     RC-0291         0
# 461                               Lock Ring     LR-2398         0
# 352                Front Derailleur Linkage     FL-2301         0
# 351                   Front Derailleur Cage     FC-3982         0
# 332                               Freewheel     FH-2981         0
# 320                         Chainring Bolts     CB-2903         0
#
#            FinishedGoodsFlag   Color  SafetyStockLevel  ReorderPoint  \
# ProductID
# 774                        1  Silver               100            75
# 771                        1  Silver               100            75
# 772                        1  Silver               100            75
# 773                        1  Silver               100            75
# 779                        1  Silver               100            75
# 781                        1  Silver               100            75
# 780                        1  Silver               100            75
# 739                        1  Silver               500           375
# 740                        1  Silver               500           375
# 741                        1  Silver               500           375
# 742                        1  Silver               500           375
# 748                        1  Silver               500           375
# 980                        1  Silver               100            75
# 981                        1  Silver               100            75
# 982                        1  Silver               100            75
# 983                        1  Silver               100            75
# 988                        1  Silver               100            75
# 984                        1  Silver               100            75
# 985                        1  Silver               100            75
# 986                        1  Silver               100            75
# 987                        1  Silver               100            75
# 942                        1  Silver               500           375
# 904                        1  Silver               500           375
# 905                        1  Silver               500           375
# 906                        1  Silver               500           375
# 919                        1  Silver               500           375
# 944                        1  Silver               500           375
# 920                        1  Silver               500           375
# 917                        1  Silver               500           375
# 918                        1  Silver               500           375
# 894                        1  Silver               500           375
# 907                        1  Silver               500           375
# 948                        1  Silver               500           375
# 945                        1  Silver               500           375
# 869                        1   Black                 4             3
# 868                        1   Black                 4             3
# 867                        1   Black                 4             3
# 880                        1  Silver                 4             3
# 952                        1  Silver               500           375
# 321                        0  Silver              1000           750
# 679                        0  Silver               500           375
# 461                        0  Silver              1000           750
# 352                        0  Silver               800           600
# 351                        0  Silver               800           600
# 332                        0  Silver               500           375
# 320                        0  Silver              1000           750
#
#            StandardCost  ListPrice Size  ... ProductLine Class  Style  \
# ProductID                                ...
# 774           1912.1544    3399.99   48  ...          M     H      U
# 771           1912.1544    3399.99   38  ...          M     H      U
# 772           1912.1544    3399.99   42  ...          M     H      U
# 773           1912.1544    3399.99   44  ...          M     H      U
# 779           1265.6195    2319.99   38  ...          M     H      U
# 781           1265.6195    2319.99   46  ...          M     H      U
# 780           1265.6195    2319.99   42  ...          M     H      U
# 739            747.2002    1364.50   42  ...          M     H      U
# 740            706.8110    1364.50   44  ...          M     H      U
# 741            706.8110    1364.50   48  ...          M     H      U
# 742            747.2002    1364.50   46  ...          M     H      U
# 748            747.2002    1364.50   38  ...          M     H      U
# 980            419.7784     769.49   38  ...          M     M      W
# 981            419.7784     769.49   40  ...          M     M      W
# 982            419.7784     769.49   42  ...          M     M      W
# 983            419.7784     769.49   46  ...          M     M      W
# 988            308.2179     564.99   52  ...          M     L      U
# 984            308.2179     564.99   40  ...          M     L      U
# 985            308.2179     564.99   42  ...          M     L      U
# 986            308.2179     564.99   44  ...          M     L      U
# 987            308.2179     564.99   48  ...          M     L      U
# 942            199.3757     364.09   38  ...          M     M      W
# 904            199.3757     364.09   40  ...          M     M      W
# 905            199.3757     364.09   42  ...          M     M      W
# 906            199.3757     364.09   46  ...          M     M      W
# 919            144.5938     264.05   48  ...          M     L      U
# 944            144.5938     264.05   40  ...          M     L      U
# 920            144.5938     264.05   52  ...          M     L      U
# 917            144.5938     264.05   42  ...          M     L      U
# 918            144.5938     264.05   44  ...          M     L      U
# 894             53.9282     121.46  NaN  ...         NaN   NaN    NaN
# 907             47.2860     106.50  NaN  ...         NaN   NaN    NaN
# 948             47.2860     106.50  NaN  ...         NaN   NaN    NaN
# 945             40.6216      91.49  NaN  ...         NaN   NaN    NaN
# 869             26.1763      69.99    L  ...          M    NaN     W
# 868             26.1763      69.99    M  ...          M    NaN     W
# 867             26.1763      69.99    S  ...          M    NaN     W
# 880             20.5663      54.99   70  ...          S    NaN    NaN
# 952              8.9866      20.24  NaN  ...         NaN   NaN    NaN
# 321              0.0000       0.00  NaN  ...         NaN   NaN    NaN
# 679              0.0000       0.00  NaN  ...         NaN   NaN    NaN
# 461              0.0000       0.00  NaN  ...         NaN   NaN    NaN
# 352              0.0000       0.00  NaN  ...         NaN   NaN    NaN
# 351              0.0000       0.00  NaN  ...         NaN   NaN    NaN
# 332              0.0000       0.00  NaN  ...         NaN   NaN    NaN
# 320              0.0000       0.00  NaN  ...         NaN   NaN    NaN
#
#            ProductSubcategoryID ProductModelID        SellStartDate  \
# ProductID
# 774                         1.0           19.0  2011-05-31 00:00:00
# 771                         1.0           19.0  2011-05-31 00:00:00
# 772                         1.0           19.0  2011-05-31 00:00:00
# 773                         1.0           19.0  2011-05-31 00:00:00
# 779                         1.0           20.0  2012-05-30 00:00:00
# 781                         1.0           20.0  2012-05-30 00:00:00
# 780                         1.0           20.0  2012-05-30 00:00:00
# 739                        12.0            5.0  2011-05-31 00:00:00
# 740                        12.0            5.0  2011-05-31 00:00:00
# 741                        12.0            5.0  2011-05-31 00:00:00
# 742                        12.0            5.0  2011-05-31 00:00:00
# 748                        12.0            5.0  2011-05-31 00:00:00
# 980                         1.0           22.0  2013-05-30 00:00:00
# 981                         1.0           22.0  2013-05-30 00:00:00
# 982                         1.0           22.0  2013-05-30 00:00:00
# 983                         1.0           22.0  2013-05-30 00:00:00
# 988                         1.0           23.0  2013-05-30 00:00:00
# 984                         1.0           23.0  2013-05-30 00:00:00
# 985                         1.0           23.0  2013-05-30 00:00:00
# 986                         1.0           23.0  2013-05-30 00:00:00
# 987                         1.0           23.0  2013-05-30 00:00:00
# 942                        12.0           15.0  2013-05-30 00:00:00
# 904                        12.0           15.0  2013-05-30 00:00:00
# 905                        12.0           15.0  2013-05-30 00:00:00
# 906                        12.0           15.0  2013-05-30 00:00:00
# 919                        12.0            8.0  2013-05-30 00:00:00
# 944                        12.0            8.0  2013-05-30 00:00:00
# 920                        12.0            8.0  2013-05-30 00:00:00
# 917                        12.0            8.0  2013-05-30 00:00:00
# 918                        12.0            8.0  2013-05-30 00:00:00
# 894                         9.0          127.0  2013-05-30 00:00:00
# 907                         6.0          128.0  2013-05-30 00:00:00
# 948                         6.0          102.0  2013-05-30 00:00:00
# 945                         9.0          103.0  2013-05-30 00:00:00
# 869                        22.0           37.0  2013-05-30 00:00:00
# 868                        22.0           37.0  2013-05-30 00:00:00
# 867                        22.0           37.0  2013-05-30 00:00:00
# 880                        32.0          107.0  2013-05-30 00:00:00
# 952                         7.0           98.0  2013-05-30 00:00:00
# 321                         NaN            NaN  2008-04-30 00:00:00
# 679                         NaN            NaN  2008-04-30 00:00:00
# 461                         NaN            NaN  2008-04-30 00:00:00
# 352                         NaN            NaN  2008-04-30 00:00:00
# 351                         NaN            NaN  2008-04-30 00:00:00
# 332                         NaN            NaN  2008-04-30 00:00:00
# 320                         NaN            NaN  2008-04-30 00:00:00
#
#                    SellEndDate  DiscontinuedDate  \
# ProductID
# 774        2012-05-29 00:00:00               NaN
# 771        2012-05-29 00:00:00               NaN
# 772        2012-05-29 00:00:00               NaN
# 773        2012-05-29 00:00:00               NaN
# 779                        NaN               NaN
# 781                        NaN               NaN
# 780                        NaN               NaN
# 739                        NaN               NaN
# 740        2012-05-29 00:00:00               NaN
# 741        2012-05-29 00:00:00               NaN
# 742                        NaN               NaN
# 748                        NaN               NaN
# 980                        NaN               NaN
# 981                        NaN               NaN
# 982                        NaN               NaN
# 983                        NaN               NaN
# 988                        NaN               NaN
# 984                        NaN               NaN
# 985                        NaN               NaN
# 986                        NaN               NaN
# 987                        NaN               NaN
# 942                        NaN               NaN
# 904                        NaN               NaN
# 905                        NaN               NaN
# 906                        NaN               NaN
# 919                        NaN               NaN
# 944                        NaN               NaN
# 920                        NaN               NaN
# 917                        NaN               NaN
# 918                        NaN               NaN
# 894                        NaN               NaN
# 907                        NaN               NaN
# 948                        NaN               NaN
# 945                        NaN               NaN
# 869                        NaN               NaN
# 868                        NaN               NaN
# 867                        NaN               NaN
# 880                        NaN               NaN
# 952                        NaN               NaN
# 321                        NaN               NaN
# 679                        NaN               NaN
# 461                        NaN               NaN
# 352                        NaN               NaN
# 351                        NaN               NaN
# 332                        NaN               NaN
# 320                        NaN               NaN
#
#                                           rowguid  \
# ProductID
# 774        {BA5551DF-C9EE-4B43-B3CA-8C19D0F9384D}
# 771        {CA74B54E-FC30-4464-8B83-019BFD1B2DBB}
# 772        {BBFFF5A5-4BDC-49A9-A5AD-7584ADFFE808}
# 773        {155FD77E-D6D6-43F0-8A5B-4A8305EB45CD}
# 779        {3A45D835-ABAE-4806-AC03-C53ABCD3B974}
# 781        {20799030-420C-496A-9922-09189C2B457E}
# 780        {CE4849B4-56E6-4B50-808B-9BDE67CC4704}
# 739        {8AE32663-8D6F-457D-8343-5B181FEC43A7}
# 740        {1909C60C-C490-411D-B3E6-12DDD7832482}
# 741        {B181EC1F-CA20-4724-B2EB-15F3E455142E}
# 742        {A189D86E-D923-4336-B13D-A5DB6F426540}
# 748        {F246ACAA-A80B-40EC-9208-02EDEF885129}
# 980        {7A927632-99A4-4F24-ADCE-0062D2D113D9}
# 981        {0A72791C-A984-4733-AE4E-2B4373CFD7CD}
# 982        {4EA4FE06-AAEA-42D4-A9D9-69F6A9A4A042}
# 983        {0B0C8EE4-FF2D-438E-9CAC-464783B86191}
# 988        {CAD60945-183E-4AB3-A70C-3F5BAC6BF134}
# 984        {B96C057B-6416-4851-8D59-BCB37C8E6E51}
# 985        {B8D1B5D9-8A39-4097-A04A-56E95559B534}
# 986        {E8CEC794-E8E2-4312-96A7-4832E573D3FC}
# 987        {77EF419F-481F-40B9-BDB9-7E6678E550E3}
# 942        {BA3646B0-1487-426E-AB4E-57D42E6F9233}
# 904        {A7DDE43E-F7D5-4075-A0C1-C866AD7AA154}
# 905        {D4A2FCAD-1E63-4EBD-863C-5A7C48D5B8D9}
# 906        {82025C63-7B28-412D-92C1-408E0E6AE646}
# 919        {8DFEF6F2-91A8-4884-8949-B2551218B37A}
# 944        {756F862E-40CC-4DFC-B189-716D0DDA5FF9}
# 920        {F230BAAC-5951-4EB1-B1E8-94C2CA2B37FA}
# 917        {37BD4D2B-346B-4C6B-8F3F-85C084282529}
# 918        {393A4D00-7428-41F0-A48A-AF26B00E9A9C}
# 894        {5EBFCF02-4E3E-443A-AD60-5AEEF28DAC76}
# 907        {5946F163-93F0-4141-B17E-55D9778CC274}
# 948        {C1813164-1B4B-42D1-9007-4E5F9AEE0E19}
# 945        {448E9E7B-9548-4A4C-ABB3-853686AA7517}
# 869        {1A66B244-5CA0-4153-B539-AE048D14FAEC}
# 868        {968E3610-E583-42E8-8AB6-484A799B1774}
# 867        {22616FD2-B99F-4F7D-ACF6-33DFF66D42D2}
# 880        {A99D90C0-05E2-4E44-AD90-C55C9F0784DE}
# 952        {5D27E2A5-27EC-4CCB-BA2C-FC980FFE6708}
# 321        {3314B1D7-EF69-4431-B6DD-DC75268BD5DF}
# 679        {912B03EA-4447-48C8-85DA-09B80AB26340}
# 461        {AECA59DA-B61C-4976-8316-97E14CD4EFF1}
# 352        {88ED2E08-E775-4915-B506-831600B773FD}
# 351        {01C901E3-4323-48ED-AB9E-9BFDA28BDEF6}
# 332        {D864879A-E8B1-4F7B-BAFA-1F136089C2C8}
# 320        {7BE38E48-B7D6-4486-888E-F53C26735101}
#
#                             ModifiedDate
# ProductID
# 774        2014-02-08 10:01:36.827000000
# 771        2014-02-08 10:01:36.827000000
# 772        2014-02-08 10:01:36.827000000
# 773        2014-02-08 10:01:36.827000000
# 779        2014-02-08 10:01:36.827000000
# 781        2014-02-08 10:01:36.827000000
# 780        2014-02-08 10:01:36.827000000
# 739        2014-02-08 10:01:36.827000000
# 740        2014-02-08 10:01:36.827000000
# 741        2014-02-08 10:01:36.827000000
# 742        2014-02-08 10:01:36.827000000
# 748        2014-02-08 10:01:36.827000000
# 980        2014-02-08 10:01:36.827000000
# 981        2014-02-08 10:01:36.827000000
# 982        2014-02-08 10:01:36.827000000
# 983        2014-02-08 10:01:36.827000000
# 988        2014-02-08 10:01:36.827000000
# 984        2014-02-08 10:01:36.827000000
# 985        2014-02-08 10:01:36.827000000
# 986        2014-02-08 10:01:36.827000000
# 987        2014-02-08 10:01:36.827000000
# 942        2014-02-08 10:01:36.827000000
# 904        2014-02-08 10:01:36.827000000
# 905        2014-02-08 10:01:36.827000000
# 906        2014-02-08 10:01:36.827000000
# 919        2014-02-08 10:01:36.827000000
# 944        2014-02-08 10:01:36.827000000
# 920        2014-02-08 10:01:36.827000000
# 917        2014-02-08 10:01:36.827000000
# 918        2014-02-08 10:01:36.827000000
# 894        2014-02-08 10:01:36.827000000
# 907        2014-02-08 10:01:36.827000000
# 948        2014-02-08 10:01:36.827000000
# 945        2014-02-08 10:01:36.827000000
# 869        2014-02-08 10:01:36.827000000
# 868        2014-02-08 10:01:36.827000000
# 867        2014-02-08 10:01:36.827000000
# 880        2014-02-08 10:01:36.827000000
# 952        2014-02-08 10:01:36.827000000
# 321        2014-02-08 10:01:36.827000000
# 679        2014-02-08 10:01:36.827000000
# 461        2014-02-08 10:01:36.827000000
# 352        2014-02-08 10:01:36.827000000
# 351        2014-02-08 10:01:36.827000000
# 332        2014-02-08 10:01:36.827000000
# 320        2014-02-08 10:01:36.827000000
#
# [46 rows x 24 columns]

# %% [markdown]
# ## Recap
#
# We covered a lot of ground! It's ok if this takes a while to gel.
#
# ```python
#
# # basic DataFrame operations
# df.head()
# df.tail()
# df.shape
# df.columns
# df.Index
#
# # selecting columns
# df.column_name
# df['column_name']
#
# # renaming columns
# df.rename({'old_name':'new_name'}, inplace=True)
# df.columns = ['new_column_a', 'new_column_b']
#
# # notable columns operations
# df.describe() # five number summary
# df['col1'].nunique() # number of unique values
# df['col1'].value_counts() # number of occurrences of each value in column
#
# # filtering
# df[ df['col1'] < 50 ] # filter column to be less than 50
# df[ (df['col1'] == value1) & (df['col2'] > value2) ] # filter column where col1 is equal to value1 AND col2 is greater to value 2
#
# # sorting
# df.sort_values(by='column_name', ascending = False) # sort biggest to smallest
#
# ```
#
#
# It's common to refer back to your own code *all the time.* Don't hesistate to reference this guide! 🐼
